# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('autos_dataset.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ## 1.Histogram

# %% [markdown]
# A histogram takes in a series of data and divides the data into a number of bins. It then plots the frequency data points in each bin (i.e. the interval of points). It is useful in understanding the count of data ranges.
#
# When to use: We should use histogram when we need the count of the variable in a plot.

# %%
plt.hist(df['city-mpg'],
        facecolor='peru',
        bins=10)
plt.show()

# %%
plt.hist(df['city-mpg'],facecolor='grey',bins=10)
plt.show()

# %% [markdown]
# components of histogram:
#     n: contains a frequency of each bin
#     bins: Represents the middle value of each bin
#     patches: the patch object for the rectangle shape representing each bar

# %%
n, bins, patches =plt.hist(df['city-mpg'],
                          facecolor='peru',
                          edgecolor='black',
                          bins=10)
print('n:',n)
print('bins:',bins)
print('patches:',patches)
# Out:
# n: [12. 46. 24. 56. 18. 31. 15.  0.  1.  2.]
# bins: [13.  16.6 20.2 23.8 27.4 31.  34.6 38.2 41.8 45.4 49. ]
# patches: <BarContainer object of 10 artists>

# %%
#to plot cumulative plot
plt.hist(df['city-mpg'],
         facecolor='peru',
         edgecolor='black',
         bins=10,
        cumulative=True)
plt.show()

# %% [markdown]
# ##### Multiple Histogram

# %%
plt.hist(df['city-mpg'],
        facecolor='orangered',
        edgecolor='maroon',
        bins=8)

plt.hist(df['highway-mpg'],
        facecolor='peru',
        edgecolor='blue',
        bins=10,
        alpha=0.3)
plt.show()

# %% [markdown]
# ## 2. Pie Chart

# %%
plt.pie(df['fuel-type'].value_counts(), labels=df['fuel-type'].unique())
plt.axis('equal')
plt.show()

# %% [markdown]
# components of pie chart:
#     wedges:a list of patch objects representing each wedge
#     texts:list of text objects representing the labels
#     autotexts:list of text object for the numeric values

# %%
wedges, text, autotexts =plt.pie(df['fuel-type'].value_counts(),labels=df['fuel-type'].unique(),autopct='%.2f')
plt.axis('equal')

print('wedges:',wedges)
print('texts:',text)
print('autotexts:',autotexts)
# Out:
# wedges: [<matplotlib.patches.Wedge object at 0x000001AB3D5093D0>, <matplotlib.patches.Wedge object at 0x000001AB3D509AF0>]
# texts: [Text(-1.048736003975903, 0.3318927446701041, 'gas'), Text(1.048735972901857, -0.33189284285985376, 'diesel')]
# autotexts: [Text(-0.5720378203504926, 0.18103240618369312, '90.24'), Text(0.5720378034010128, -0.1810324597417384, '9.76')]

# %%
#chart customization

colors=['darkorange','sandybrown']
plt.pie(df['fuel-type'].value_counts(), 
        labels=df['fuel-type'].unique(),
        colors=colors,
        autopct='%.2f')

plt.axis('equal')
plt.show()

# %%
#to explode chart

explode=(0,0.1,0,0.2,0.3)
colorsp=['darkorange','sandybrown','darksalmon','orangered','chocolate']
plt.pie(df['body-style'].value_counts(),
       labels=df['body-style'].unique(),
       colors=colorsp,
       explode=explode,
       autopct='%.2f')

plt.show()

# %% [markdown]
# ## 3. Box Plot

# %%
plt.boxplot(df['wheel-base'],
           patch_artist=True,
           notch=True)
plt.show()

# %%
exams=pd.read_csv('exams.csv')
exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
score_card=exams[['math score','reading score','writing score']]
score_card.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
score_card.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
#for ploting boxplot we convert data to array
score_array=np.array(score_card)
score_array
# Out:
# array([[ 69,  61,  58],
#        [ 47,  65,  69],
#        [ 66,  52,  53],
#        [ 88,  89,  82],
#        [ 62,  82,  76],
#        [ 47,  69,  60],
#        [ 71,  66,  74],
#        [ 57,  62,  60],
#        [ 60,  67,  65],
#        [ 74,  72,  76],
#        [ 77,  71,  67],
#        [ 69,  79,  83],
#        [ 65,  62,  56],
#        [ 55,  58,  51],
#        [ 78,  88,  91],
#        [ 70,  72,  72],
#        [ 55,  69,  55],
#        [ 68,  68,  62],
#        [ 73,  62,  58],
#        [ 54,  50,  51],
#        [ 81,  76,  77],
#        [ 70,  76,  73],
#        [ 64,  62,  63],
#        [ 51,  66,  63],
#        [ 49,  50,  43],
#        [ 83,  80,  82],
#        [ 86,  92,  81],
#        [ 83,  89,  94],
#        [ 61,  77,  68],
#        [ 55,  50,  44],
#        [ 56,  59,  55],
#        [ 46,  57,  61],
#        [ 68,  60,  52],
#        [ 78,  75,  69],
#        [ 85,  94,  93],
#        [ 95,  99,  95],
#        [ 82,  74,  78],
#        [ 94,  85,  96],
# ...

# %%
colors=['blue','green','grey']

bp=plt.boxplot(score_array,
              patch_artist=True,
              notch=True)

for i in range(len(bp['boxes'])):
    bp['boxes'][i].set(facecolor=colors[i])
    bp['caps'][2*i + 1].set(color=colors[i])
    
plt.xticks([1,2,3],['Math','Reading','Writing'])
plt.show()

# %% [markdown]
# ## 4. Violin Plot

# %%
plt.violinplot(df['wheel-base'])
plt.show()

# %%
vp=plt.violinplot(score_array,
                 showmedians=True)

plt.xticks([1,2,3],['Math','Reading','Writing'])

for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolors=colors[i])
    
plt.show()

# %% [markdown]
# ## 5. Lineplot

# %%
stock=pd.read_csv('stocks.csv')
stock.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
stock['Date']=pd.to_datetime(stock['Date'])
stock.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
#compare stock side by side
fig=plt.figure(figsize=(10,6))

ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.05,0.65,0.5,0.3])

ax1.set_title('AAPL Vs IBM')
ax1.plot(stock['Date'],stock['AAPL'],color='green')

ax2.plot(stock['Date'],stock['IBM'],color='blue')
plt.show()

# %%
#figsize for width and height of plot

fig=plt.figure(figsize=(15,7))
fig.suptitle('stock size comparison 2007-2017',
             fontsize=20)
ax1=fig.add_subplot(231)
ax1.set_title('MSFT')

ax1.plot(stock['Date'],
        stock['MSFT'],
        color='green')

ax2=fig.add_subplot(232)
ax2.set_title('GOOG')

ax2.plot(stock['Date'],
        stock['GOOG'],
        color='purple')

ax3=fig.add_subplot(233)
ax3.set_title('SBUX')

ax3.plot(stock['Date'],
        stock['SBUX'],
        color='magenta')

ax4=fig.add_subplot(234)
ax4.set_title('ADBE')

ax4.plot(stock['Date'],
        stock['ADBE'],
        color='orange')

ax5=fig.add_subplot(235)
ax5.set_title('NFLX')

ax5.plot(stock['Date'],
        stock['NFLX'],
        color='chocolate')

ax5=fig.add_subplot(236)
ax5.set_title('ORCL')

ax5.plot(stock['Date'],
        stock['ORCL'],
        color='pink')

plt.show()

# %% [markdown]
# ## 6. TwinAxis

# %% [markdown]
# TwinAxis helps in visualizing plotting 2 plots w.r.t to the y-axis and same x-axis.
# When to use: It should when we require 2 plots or grouped data in the same direction.
#
# Eg: Population, GDP data in the same x-axis (Date).

# %%
austin_weather=pd.read_csv('Datasets/austin_weather.csv')
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
austin_weather=austin_weather[['Date','TempAvgF','WindAvgMPH']].head(30)
austin_weather
# Out:
#           Date  TempAvgF WindAvgMPH
# 0   2013-12-21        60          4
# 1   2013-12-22        48          6
# 2   2013-12-23        45          3
# 3   2013-12-24        46          4
# 4   2013-12-25        50          2
# 5   2013-12-26        48          3
# 6   2013-12-27        53          1
# 7   2013-12-28        51          2
# 8   2013-12-29        50          5
# 9   2013-12-30        40          5
# 10  2013-12-31        46          1
# 11  2014-01-01        54          4
# 12  2014-01-02        44          8
# 13  2014-01-03        43          4
# 14  2014-01-04        57          7
# 15  2014-01-05        47         10
# 16  2014-01-06        29          7
# 17  2014-01-07        35          5
# 18  2014-01-08        47          1
# 19  2014-01-09        62          3
# 20  2014-01-10        65          6
# 21  2014-01-11        62          3
# 22  2014-01-12        57          4
# 23  2014-01-13        57          7
# 24  2014-01-14        57          5
# ...

# %%
#subplot for ploting figures
fig,ax_tempf=plt.subplots()

#similar to fig=plt.figure(figsize(12,6))
fig.set_figwidth(12)
fig.set_figheight(6)

#set x label which is common
ax_tempf.set_xlabel('Date')

#bottom=false disable ticks and label bottom disable x-axis labels
ax_tempf.tick_params(axis='x',
                    bottom=False,
                    labelbottom=False)

#set left y axis label
ax_tempf.set_ylabel('Temp(F)',
                   color='red',
                   size='large')

#set label color and label size for the left y-axis
ax_tempf.tick_params(axis='y',
                    labelcolor='red',
                    labelsize='large')

#plot avg temp on y-axis on left
ax_tempf.plot(austin_weather['Date'],
             austin_weather['TempAvgF'],
             color='red')

#twinx sets the same x-axis for both the plots
ax_precip=ax_tempf.twinx()

#set right y-axis label
ax_precip.set_ylabel('Avg Wind speed',
                    color='blue',
                    size='x-large')

#set label color and label size to right y-axis
ax_precip.tick_params(axis='y',
                     labelcolor='blue',
                     labelsize='large')

#plot windAvg on y-axis to the right
ax_precip.plot(austin_weather['Date'],
              austin_weather['WindAvgMPH'],
              color='blue')

#ax_precip.legend(0)

plt.show()

# %% [markdown]
# ### Twin axis for the same data

# %% [markdown]
# if same data can be expressed in different units, we can configure our axis to display both units on two axes

# %%
def fahrenheit2celcius(f):
    return (f-32)*5/9

# %%
#subplot for plotting figure
fig, ax=plt.subplots()
fig=plt.figure(figsize=(12,6))

#set x label which is common
ax.set_xlabel('Date')

#disable bottom ticks and labels
ax.tick_params(axis='x',
              bottom=False,
              labelbottom=False)

#set left y-axis label
ax.set_ylabel('Temp(F)',color='red',size='x-large')

#set label color and label size on left y-axis
ax.tick_params(axis='y',
              labelcolor='red',
              labelsize='large')

#plot AvgTemp on y-axis to the left
ax.plot(austin_weather['Date'],
       austin_weather['TempAvgF'],
       color='green')

#twinx set the same axis for both plot
ax_t=ax.twinx()

#get ymin and ymax of AvgTemp in Fahrenheit
ymin, ymax = ax.get_ylim()

#set ymin and ymin of AvgTemp in Fahrenheit to AvgTemp in celsius
ax_t.set_ylim((fahrenheit2celcius(ymin),fahrenheit2celcius(ymax)))


#set right y-axis label
ax_t.set_ylabel('Temp(C)',
               color='blue',
               size='x-large')

#set label color and label size on right y-axis
ax_t.tick_params(axis='y',
                labelcolor='blue',
                labelsize='large')
plt.show()

# %% [markdown]
# ## 7. Stack Plot and Stem Plot

# %% [markdown]
# Stack Plot : visualizes dat ain stacks and shows distribution of data over time
#
# when to use: It is used for checking multiple variable area plots in a single plot
#
# eg. It is useful in understanding the change of distribution in multiple variables over an interval

# %%
np_data=pd.read_csv('Datasets/national_parks.csv')
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x=np_data['Year']
y=np.vstack([np_data['Badlands'],
            np_data['GrandCanyon'],
            np_data['BryceCanyon']])

# %%
#label for each stack
labels=['Badlands','GrandCanyon','BryceCanyon']

#color for each stack
colors=['sandybrown','tomato','skyblue']

#similar to pandas df.plot.area()
plt.stackplot(x, y, 
              labels=labels,
              colors=colors, 
              edgecolor='black')

#plot legends to upperleft of figure
plt.legend(loc=2)
plt.show()

# %% [markdown]
# #### Precentage stack area chart

# %% [markdown]
# stack plots based on percentage in distribution

# %%
plt.figure(figsize=(10,7))

data_prep=np_data.divide(np_data.sum(axis=1),axis=0)

plt.stackplot(x,data_prep['Badlands'],data_prep['GrandCanyon'],data_prep['BryceCanyon'],
             edgecolor='black',
             colors=colors,
             labels=labels)

plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.show()

# %% [markdown]
# Stem plot: similar to stack plot but helps to view negative numbers, i.e difference in data over time

# %%
np_stem=np_data.copy()

# %%
np_stem[['Badlands','GrandCanyon','BryceCanyon']]=np_data[['Badlands','GrandCanyon','BryceCanyon']].diff()
np_stem.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961       NaN          NaN          NaN
# 1  1962  211500.0     194400.0     -13800.0
# 2  1963   29200.0      92100.0      38500.0
# 3  1964    5800.0      37100.0      10800.0
# 4  1965   11500.0     112600.0      66500.0

# %%
plt.figure(figsize=(15,11))

plt.suptitle('Change in number of visitors')

plt.subplot(311)
plt.stem(np_stem['Year'],
        np_stem['Badlands'],
        markerfmt='b_',
        linefmt='r--',
        basefmt='g:')
plt.title('Badlands')

plt.subplot(312)
plt.stem(np_stem['Year'],
        np_stem['GrandCanyon'],
        markerfmt='b_',
        linefmt='r--',
        basefmt='g:')
plt.title('GrandCanyon')

plt.subplot(313)
plt.stem(np_stem['Year'],
        np_stem['BryceCanyon'],
        markerfmt='b_',
        linefmt='r--',
        basefmt='g:')
plt.title('BryceCanyon')

plt.show()

# %% [markdown]
# ## 8. Bar Plot

# %% [markdown]
# Bar Plot shows the distribution of data over several groups. It is commonly confused with a histogram which only takes numerical data for plotting. It helps in comparing multiple numeric values.
#
# When to use: It is used when to compare between several groups.
#
# Eg: Student marks in an exam.

# %%
countries=pd.read_csv('Datasets/countries.csv')
countries.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_2007=countries[countries['year']==2007]
top_10=data_2007.sort_values('population',ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))

x=range(10)
plt.bar(x,top_10['population']/10**9)
plt.xticks(x,top_10['country'])
plt.xlabel('countries')
plt.ylabel('population in billions')
plt.title('10 most populated countries in 2007')
plt.show()

# %% [markdown]
# ## 9.Scatter plot

# %% [markdown]
# Scatter plot helps in visualizing 2 numeric variables. It helps in identifying the relationship of the data with each variable i.e correlation or trend patterns. It also helps in detecting outliers in the plot.
#
# When to use: It is used in Machine learning concepts like regression, where x and y are continuous variables. It is also used in clustering scatters or outlier detection.

# %%
plt.scatter(data_2007['gdpPerCapita'],
           data_2007['lifeExpectancy'])
plt.title('Life Expectancy vs GDP Per Capita in 2007 ')
plt.xlabel('GDP per Capita($)')
plt.ylabel('Life Expectancy')

plt.show()

# %%
data_2007['gdpPerCapita'].corr(data_2007['lifeExpectancy'])
# Out:
# 0.6786623986777587

# %%
plt.scatter(np.log10(data_2007['gdpPerCapita']),data_2007['lifeExpectancy'])
plt.title('Life Expectancy vs GDP Per Capita in 2007 ')
plt.xlabel('GDP per Capita($)')
plt.ylabel('Life Expectancy')
plt.show()

# %%
np.log10(data_2007['gdpPerCapita']).corr(data_2007['lifeExpectancy'])
# Out:
# 0.9999999999999998

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(countries['year'],countries['gdpPerCapita'],countries['lifeExpectancy'],s=30)
plt.show()

# %%
#end
